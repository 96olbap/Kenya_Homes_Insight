# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    data = pd.read_csv("real_estate_nrb_cleaned.csv", sep=';', on_bad_lines='warn')
    # If you want to see which lines are causing errors, you can switch to 'warn'.
    # data = pd.read_csv("real_estate_nrb_cleaned.csv", sep=';', on_bad_lines='warn')
    print(data.head())
except Exception as e:
    print("An error occurred:", e)
# Out:
#                                              Title   Category  \
# 0  4 Bed Townhouse With En Suite At Five Star Road  Townhouse
# 1   5 Bed Townhouse With En Suite In Spring Valley  Townhouse
# 2   4 Bed Townhouse With En Suite At Owashika Road  Townhouse
# 3      5 Bed Townhouse With En Suite In Nyali Area      Villa
# 4       3 Bed House With En Suite At Kangundo Road   Bungalow
#
#                                     Location  Beds  Baths     Price
# 0                    Five Star Road, South C     4    4.0  20000000
# 1                   Spring Valley, Westlands     5    6.0  90000000
# 2                   Owashika Road, Lavington     4    4.0  58500000
# 3                          Nyali Area, Nyali     5    5.0  45000000
# 4  Kangundo Road, Kamulu, Kamulu Joska Malaa     3    3.0   7300000

# %%
data
# Out:
#                                                 Title   Category  \
# 0     4 Bed Townhouse With En Suite At Five Star Road  Townhouse
# 1      5 Bed Townhouse With En Suite In Spring Valley  Townhouse
# 2      4 Bed Townhouse With En Suite At Owashika Road  Townhouse
# 3         5 Bed Townhouse With En Suite In Nyali Area      Villa
# 4          3 Bed House With En Suite At Kangundo Road   Bungalow
# ...                                               ...        ...
# 1355       4 Bed Townhouse With En Suite At Lavington  Townhouse
# 1356           3 Bed House With En Suite At Palm Road      Other
# 1357       5 Bed Townhouse With En Suite In Lavington      Villa
# 1358            5 Bed House With En Suite At Kitisuri      Other
# 1359             4 Bed House With En Suite At Loresho      Other
#
#                                        Location  Beds  Baths      Price
# 0                       Five Star Road, South C     4    4.0   20000000
# 1                      Spring Valley, Westlands     5    6.0   90000000
# 2                      Owashika Road, Lavington     4    4.0   58500000
# 3                             Nyali Area, Nyali     5    5.0   45000000
# 4     Kangundo Road, Kamulu, Kamulu Joska Malaa     3    3.0    7300000
# ...                                         ...   ...    ...        ...
# 1355                       Lavington, Lavington     4    4.0   50000000
# 1356                         Palm Road, Malindi     3    3.0   14000000
# 1357                                  Lavington     5    5.0   65000000
# 1358              Kitisuri, Kitisuru, Westlands     5    NaN  376250000
# 1359                Loresho, Loresho, Westlands     4    NaN   75000000
#
# [1360 rows x 6 columns]

# %% [markdown]
# # Explore the data to check for null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360 entries, 0 to 1359
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1360 non-null   object
#  1   Category  1360 non-null   object
#  2   Location  1360 non-null   object
#  3   Beds      1360 non-null   int64
#  4   Baths     1200 non-null   float64
#  5   Price     1360 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 63.9+ KB

# %% [markdown]
# Drop null values

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1357
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1200 non-null   object
#  1   Category  1200 non-null   object
#  2   Location  1200 non-null   object
#  3   Beds      1200 non-null   int64
#  4   Baths     1200 non-null   float64
#  5   Price     1200 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 65.6+ KB

# %% [markdown]
# # Split the data into training and testing datasets

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['Price'], axis=1)
y = data['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#                                                   Title   Category  \
# 452                  6 Bed Villa With En Suite In Karen      Villa
# 179         4 Bed Townhouse With En Suite At Links Road  Townhouse
# 807              3 Bed Townhouse With En Suite In Thika  Townhouse
# 495      4 Bed Townhouse With En Suite At Owashika Road  Townhouse
# 585                  5 Bed House With En Suite In Runda      Other
# ...                                                 ...        ...
# 1284        4 Bed Townhouse With En Suite At Links Road  Townhouse
# 264         4 Bed Townhouse With En Suite At Links Road  Townhouse
# 835      4 Bed Townhouse With En Suite At Owashika Road  Townhouse
# 1337                4 Bed Villa With En Suite At Mtwapa      Villa
# 850   4 Bed Townhouse With En Suite At Off Haile Sel...  Townhouse
#
#                                                Location  Beds  Baths  \
# 452                                               Karen     6    6.0
# 179                       Links Road, Nyali Area, Nyali     4    4.0
# 807                                               Thika     3    3.0
# 495                            Owashika Road, Lavington     4    4.0
# 585                                    Runda, Westlands     5    5.0
# ...                                                 ...   ...    ...
# 1284                      Links Road, Nyali Area, Nyali     4    4.0
# 264                       Links Road, Nyali Area, Nyali     4    4.0
# 835                            Owashika Road, Lavington     4    4.0
# 1337                                Jumba Ruins, Mtwapa     4    5.0
# 850   Kaugo Links Road, Muthaiga, Off Haile Selassie...     4    3.0
#
#           Price
# 452   130000000
# 179   120000000
# 807    13500000
# 495    58500000
# 585   150000000
# ...         ...
# 1284  120000000
# 264   120000000
# 835    58500000
# 1337   42000000
# 850    36500000
#
# [960 rows x 6 columns]

# %% [markdown]
# Plot histogram to explore the distribution of the different numerical features of the houses

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'Beds'}>,
#         <Axes: title={'center': 'Baths'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Plot a heatmap to visualize the correlation matrix with the target variable - price

# %%
# Select only numeric columns for correlation calculation
numeric_data = train_data.select_dtypes(include=[np.number])

corr_matrix = numeric_data.corr()

# Plotting the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %% [markdown]
# # Feature preprocessing; assign binary values to non-numeric data

# %%
train_data.Category.value_counts()
# Out:
# Category
# Townhouse    360
# Villa        309
# Other        200
# Bungalow      91
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.Category).astype(int)
# Out:
#       Bungalow  Other  Townhouse  Villa
# 452          0      0          0      1
# 179          0      0          1      0
# 807          0      0          1      0
# 495          0      0          1      0
# 585          0      1          0      0
# ...        ...    ...        ...    ...
# 1284         0      0          1      0
# 264          0      0          1      0
# 835          0      0          1      0
# 1337         0      0          0      1
# 850          0      0          1      0
#
# [960 rows x 4 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.Category).astype(int)).drop(['Category'], axis=1)

# %%
train_data
# Out:
#                                                   Title  \
# 452                  6 Bed Villa With En Suite In Karen
# 179         4 Bed Townhouse With En Suite At Links Road
# 807              3 Bed Townhouse With En Suite In Thika
# 495      4 Bed Townhouse With En Suite At Owashika Road
# 585                  5 Bed House With En Suite In Runda
# ...                                                 ...
# 1284        4 Bed Townhouse With En Suite At Links Road
# 264         4 Bed Townhouse With En Suite At Links Road
# 835      4 Bed Townhouse With En Suite At Owashika Road
# 1337                4 Bed Villa With En Suite At Mtwapa
# 850   4 Bed Townhouse With En Suite At Off Haile Sel...
#
#                                                Location  Beds  Baths  \
# 452                                               Karen     6    6.0
# 179                       Links Road, Nyali Area, Nyali     4    4.0
# 807                                               Thika     3    3.0
# 495                            Owashika Road, Lavington     4    4.0
# 585                                    Runda, Westlands     5    5.0
# ...                                                 ...   ...    ...
# 1284                      Links Road, Nyali Area, Nyali     4    4.0
# 264                       Links Road, Nyali Area, Nyali     4    4.0
# 835                            Owashika Road, Lavington     4    4.0
# 1337                                Jumba Ruins, Mtwapa     4    5.0
# 850   Kaugo Links Road, Muthaiga, Off Haile Selassie...     4    3.0
#
#           Price  Bungalow  Other  Townhouse  Villa
# 452   130000000         0      0          0      1
# 179   120000000         0      0          1      0
# 807    13500000         0      0          1      0
# 495    58500000         0      0          1      0
# 585   150000000         0      1          0      0
# ...         ...       ...    ...        ...    ...
# 1284  120000000         0      0          1      0
# 264   120000000         0      0          1      0
# 835    58500000         0      0          1      0
# 1337   42000000         0      0          0      1
# 850    36500000         0      0          1      0
#
# [960 rows x 9 columns]

# %% [markdown]
# * Plot a correlation heatmap to show the correlation matrix with the categories

# %%
# Select only numeric columns for correlation calculation
numeric_data = train_data.select_dtypes(include=[np.number])

corr_matrix = numeric_data.corr()

# Plotting the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %% [markdown]
# * Convert the Locations into binary representation

# %%
train_data.Location.value_counts()
# Out:
# Location
# Karen                                                           122
# Runda, Westlands                                                 71
# Thika                                                            66
# Owashika Road, Lavington                                         66
# Kangundo Road, Kamulu, Kamulu Joska Malaa                        66
# Ridgeways                                                        66
# Lavington, Lavington                                             64
# Nyali Area, Nyali                                                64
# Palm Road, Malindi                                               63
# Links Road, Nyali Area, Nyali                                    62
# Lavington                                                        62
# Jumba Ruins, Mtwapa                                              61
# Five Star Road, South C                                          40
# Spring Valley, Westlands                                         34
# Kaugo Links Road, Muthaiga, Off Haile Selassie Road, Nanyuki     28
# Ruiru-Githunguri Rd, Ruiru                                       25
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.Location).astype(int)
# Out:
#       Five Star Road, South C  Jumba Ruins, Mtwapa  \
# 452                         0                    0
# 179                         0                    0
# 807                         0                    0
# 495                         0                    0
# 585                         0                    0
# ...                       ...                  ...
# 1284                        0                    0
# 264                         0                    0
# 835                         0                    0
# 1337                        0                    1
# 850                         0                    0
#
#       Kangundo Road, Kamulu, Kamulu Joska Malaa  Karen  \
# 452                                           0      1
# 179                                           0      0
# 807                                           0      0
# 495                                           0      0
# 585                                           0      0
# ...                                         ...    ...
# 1284                                          0      0
# 264                                           0      0
# 835                                           0      0
# 1337                                          0      0
# 850                                           0      0
#
#       Kaugo Links Road, Muthaiga, Off Haile Selassie Road, Nanyuki  Lavington  \
# 452                                                   0                     0
# 179                                                   0                     0
# 807                                                   0                     0
# 495                                                   0                     0
# 585                                                   0                     0
# ...                                                 ...                   ...
# 1284                                                  0                     0
# 264                                                   0                     0
# 835                                                   0                     0
# 1337                                                  0                     0
# 850                                                   1                     0
#
#       Lavington, Lavington  Links Road, Nyali Area, Nyali  Nyali Area, Nyali  \
# 452                      0                              0                  0
# 179                      0                              1                  0
# 807                      0                              0                  0
# 495                      0                              0                  0
# 585                      0                              0                  0
# ...                    ...                            ...                ...
# 1284                     0                              1                  0
# 264                      0                              1                  0
# 835                      0                              0                  0
# 1337                     0                              0                  0
# 850                      0                              0                  0
#
#       Owashika Road, Lavington  Palm Road, Malindi  Ridgeways  \
# 452                          0                   0          0
# 179                          0                   0          0
# 807                          0                   0          0
# 495                          1                   0          0
# 585                          0                   0          0
# ...                        ...                 ...        ...
# 1284                         0                   0          0
# 264                          0                   0          0
# 835                          1                   0          0
# 1337                         0                   0          0
# 850                          0                   0          0
#
#       Ruiru-Githunguri Rd, Ruiru  Runda, Westlands  Spring Valley, Westlands  \
# 452                            0                 0                         0
# 179                            0                 0                         0
# 807                            0                 0                         0
# 495                            0                 0                         0
# 585                            0                 1                         0
# ...                          ...               ...                       ...
# 1284                           0                 0                         0
# 264                            0                 0                         0
# 835                            0                 0                         0
# 1337                           0                 0                         0
# 850                            0                 0                         0
#
#       Thika
# 452       0
# 179       0
# 807       1
# 495       0
# 585       0
# ...     ...
# 1284      0
# 264       0
# 835       0
# 1337      0
# 850       0
#
# [960 rows x 16 columns]

# %%
train_data_1 = train_data.join(pd.get_dummies(train_data.Location).astype(int)).drop(['Location'], axis=1)

# %%
train_data_2 = train_data_1.drop(['Title'], axis=1)

# %%
train_data_2
# Out:
#       Beds  Baths      Price  Bungalow  Other  Townhouse  Villa  \
# 452      6    6.0  130000000         0      0          0      1
# 179      4    4.0  120000000         0      0          1      0
# 807      3    3.0   13500000         0      0          1      0
# 495      4    4.0   58500000         0      0          1      0
# 585      5    5.0  150000000         0      1          0      0
# ...    ...    ...        ...       ...    ...        ...    ...
# 1284     4    4.0  120000000         0      0          1      0
# 264      4    4.0  120000000         0      0          1      0
# 835      4    4.0   58500000         0      0          1      0
# 1337     4    5.0   42000000         0      0          0      1
# 850      4    3.0   36500000         0      0          1      0
#
#       Five Star Road, South C  Jumba Ruins, Mtwapa  \
# 452                         0                    0
# 179                         0                    0
# 807                         0                    0
# 495                         0                    0
# 585                         0                    0
# ...                       ...                  ...
# 1284                        0                    0
# 264                         0                    0
# 835                         0                    0
# 1337                        0                    1
# 850                         0                    0
#
#       Kangundo Road, Kamulu, Kamulu Joska Malaa  ...  Lavington, Lavington  \
# 452                                           0  ...                     0
# 179                                           0  ...                     0
# 807                                           0  ...                     0
# 495                                           0  ...                     0
# 585                                           0  ...                     0
# ...                                         ...  ...                   ...
# 1284                                          0  ...                     0
# 264                                           0  ...                     0
# 835                                           0  ...                     0
# 1337                                          0  ...                     0
# 850                                           0  ...                     0
#
#       Links Road, Nyali Area, Nyali  Nyali Area, Nyali  \
# 452                               0                  0
# 179                               1                  0
# 807                               0                  0
# 495                               0                  0
# 585                               0                  0
# ...                             ...                ...
# 1284                              1                  0
# 264                               1                  0
# 835                               0                  0
# 1337                              0                  0
# 850                               0                  0
#
#       Owashika Road, Lavington  Palm Road, Malindi  Ridgeways  \
# 452                          0                   0          0
# 179                          0                   0          0
# 807                          0                   0          0
# 495                          1                   0          0
# 585                          0                   0          0
# ...                        ...                 ...        ...
# 1284                         0                   0          0
# 264                          0                   0          0
# 835                          1                   0          0
# 1337                         0                   0          0
# 850                          0                   0          0
#
#       Ruiru-Githunguri Rd, Ruiru  Runda, Westlands  Spring Valley, Westlands  \
# 452                            0                 0                         0
# 179                            0                 0                         0
# 807                            0                 0                         0
# 495                            0                 0                         0
# 585                            0                 1                         0
# ...                          ...               ...                       ...
# 1284                           0                 0                         0
# 264                            0                 0                         0
# 835                            0                 0                         0
# 1337                           0                 0                         0
# 850                            0                 0                         0
#
#       Thika
# 452       0
# 179       0
# 807       1
# 495       0
# 585       0
# ...     ...
# 1284      0
# 264       0
# 835       0
# 1337      0
# 850       0
#
# [960 rows x 23 columns]

# %%
# Select only numeric columns for correlation calculation
numeric_data = train_data_1.select_dtypes(include=[np.number])

corr_matrix = numeric_data.corr()

# Plotting the correlation matrix using seaborn
plt.figure(figsize=(15, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %% [markdown]
# # Import and train ML model

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data_2.drop(['Price'], axis=1), train_data_1['Price']

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data = test_data.join(pd.get_dummies(test_data.Category).astype(int)).drop(['Category'], axis=1)
test_data_1 = test_data.join(pd.get_dummies(test_data.Location).astype(int)).drop(['Location'], axis=1)
test_data_2 = test_data_1.drop(['Title'], axis=1)

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 reg.score(x_test, y_test)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:269, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
#     267     check_is_fitted(self)
# --> 269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File /usr/local/lib/python3.11/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File /usr/local/lib/python3.11/site-packages/sklearn/base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Category
# - Location
# - Title
# Feature names seen at fit time, yet now missing:
# - Bungalow
# - Five Star Road, South C
# - Jumba Ruins, Mtwapa
# - Kangundo Road, Kamulu, Kamulu Joska Malaa
# - Karen
# - ...
